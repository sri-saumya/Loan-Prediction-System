# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
sns.heatmap(data.isnull())

# %%
data.rename(columns={'CoapplicantIncome':'ExtraIncome','Credit_History':'lastloanpaid'},
           inplace=True)

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  ExtraIncome  LoanAmount  Loan_Amount_Term  lastloanpaid  \
# 0             5849          0.0         NaN             360.0           1.0
# 1             4583       1508.0       128.0             360.0           1.0
# 2             3000          0.0        66.0             360.0           1.0
# 3             2583       2358.0       120.0             360.0           1.0
# 4             6000          0.0       141.0             360.0           1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# ...

# %%
sns.heatmap(data.isnull())

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# ApplicantIncome      0
# ExtraIncome          0
# LoanAmount          22
# Loan_Amount_Term    14
# lastloanpaid        50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.Gender.fillna('Others',inplace=True)

# %%
data.Married.value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
data.Married.fillna('Yes',inplace=True)

# %%
data.Dependents.value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
np.nan
# Out:
# nan

# %%
for i in range(614):
    if(data.Married.iloc[i]=='No' and data.Dependents.iloc[i] is np.nan):
        data.Dependents.iloc[i]=0
    elif(data.Dependents.iloc[i] is np.nan):
        data.Dependents.iloc[i]=2
    else:
        pass
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed       32
# ApplicantIncome      0
# ExtraIncome          0
# LoanAmount          22
# Loan_Amount_Term    14
# lastloanpaid        50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.Self_Employed.value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
sns.swarmplot(x='Self_Employed',y='ApplicantIncome',data=data)

# %%
data.Self_Employed.fillna('Unemployed',inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# ExtraIncome          0
# LoanAmount          22
# Loan_Amount_Term    14
# lastloanpaid        50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.LoanAmount.fillna(data.LoanAmount.mean(),inplace=True)

# %%
data.LoanAmount.max()
# Out:
# 700.0

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# ExtraIncome          0
# LoanAmount           0
# Loan_Amount_Term    14
# lastloanpaid        50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.Loan_Amount_Term.value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
s=data.Loan_Amount_Term.mode()

# %%
data.Loan_Amount_Term.fillna(s.iloc[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# ExtraIncome          0
# LoanAmount           0
# Loan_Amount_Term     0
# lastloanpaid        50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.lastloanpaid.value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: lastloanpaid, dtype: int64

# %%
data.lastloanpaid.fillna(1.0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID             0
# Gender              0
# Married             0
# Dependents          0
# Education           0
# Self_Employed       0
# ApplicantIncome     0
# ExtraIncome         0
# LoanAmount          0
# Loan_Amount_Term    0
# lastloanpaid        0
# Property_Area       0
# Loan_Status         0
# dtype: int64

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  ExtraIncome  LoanAmount  Loan_Amount_Term  lastloanpaid  \
# 0             5849          0.0  146.412162             360.0           1.0
# 1             4583       1508.0  128.000000             360.0           1.0
# 2             3000          0.0   66.000000             360.0           1.0
# 3             2583       2358.0  120.000000             360.0           1.0
# 4             6000          0.0  141.000000             360.0           1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data.Gender=le.fit_transform(np.array(data.Gender).reshape(-1,1))
data.Married=le.fit_transform(np.array(data.Married).reshape(-1,1))
data.Education=le.fit_transform(np.array(data.Education).reshape(-1,1))
data.Self_Employed=le.fit_transform(np.array(data.Self_Employed).reshape(-1,1))
data.Property_Area=le.fit_transform(np.array(data.Property_Area).reshape(-1,1))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          0              0
# 1  LP001003       1        1          1          0              0
# 2  LP001005       1        1          0          0              2
# 3  LP001006       1        1          0          1              0
# 4  LP001008       1        0          0          0              0
#
#    ApplicantIncome  ExtraIncome  LoanAmount  Loan_Amount_Term  lastloanpaid  \
# 0             5849          0.0  146.412162             360.0           1.0
# 1             4583       1508.0  128.000000             360.0           1.0
# 2             3000          0.0   66.000000             360.0           1.0
# 3             2583       2358.0  120.000000             360.0           1.0
# 4             6000          0.0  141.000000             360.0           1.0
#
#    Property_Area Loan_Status
# 0              2           Y
# 1              0           N
# ...

# %%
data=data.drop('Loan_ID',axis=1)

# %%
data.Dependents.dtype
# Out:
# dtype('O')

# %%
data.Dependents=data.Dependents.astype(str)

# %%
data.Dependents=le.fit_transform(np.array(data.Dependents).reshape(-1,1))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
data.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              2             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    ExtraIncome  LoanAmount  Loan_Amount_Term  lastloanpaid  Property_Area  \
# 0          0.0  146.412162             360.0           1.0              2
# 1       1508.0  128.000000             360.0           1.0              0
# 2          0.0   66.000000             360.0           1.0              2
# 3       2358.0  120.000000             360.0           1.0              2
# 4          0.0  141.000000             360.0           1.0              2
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# ...

# %%
data.Dependents.value_counts()
# Out:
# 0    349
# 2    112
# 1    102
# 3     51
# Name: Dependents, dtype: int64

# %%
data.to_csv(r'loan_data\converted_training_data.csv',index=False)
