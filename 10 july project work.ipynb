# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'loan_data\train_loan.csv')
data.shape
# Out:
# (614, 13)

# %%
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
sns.heatmap(data.isnull())

# %%
data.rename(columns={'CoapplicantIncome':'ExtraIncome','Credit_History':'lastloanpaid'},
           inplace=True)

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  ExtraIncome  LoanAmount  Loan_Amount_Term  lastloanpaid  \
# 0             5849          0.0         NaN             360.0           1.0
# 1             4583       1508.0       128.0             360.0           1.0
# 2             3000          0.0        66.0             360.0           1.0
# 3             2583       2358.0       120.0             360.0           1.0
# 4             6000          0.0       141.0             360.0           1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# ...

# %%
sns.heatmap(data.isnull())

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# ApplicantIncome      0
# ExtraIncome          0
# LoanAmount          22
# Loan_Amount_Term    14
# lastloanpaid        50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.Gender.fillna('Others',inplace=True)

# %%
data.Married.value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
data.Married.fillna('Yes',inplace=True)

# %%
data.Dependents.value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
for i in range(len(data.Married)-1):
    if(data.Married[i]=='No' and data.Dependents[i].isnull()==True):
        data['Dependents'][i].fillna(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-abde742554c4> in <module>()
#       1 for i in range(len(data.Married)-1):
# ----> 2     if(data.Married[i]=='No' and data.Dependents[i].isnull()==True):
#       3         data['Dependents'][i].fillna(0,inplace=True)
#
# AttributeError: 'str' object has no attribute 'isnull'
